# %%
# --- Celda 1: Importación de Librerías ---
import requests
import pandas as pd
import time
import os
import json
import logging
from dotenv import load_dotenv
from collections import deque
import googlemaps # <--- LIBRERÍA NUEVA

logging.info("Librerías importadas.")

# %%
# --- Celda 2: Configuraciones Básicas ---
# Asegura que no se dupliquen los handlers si se corre la celda múltiples veces
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("001_cali_api.log"),
        logging.StreamHandler()
    ]
)

logging.info("Inicio del notebook 001_cali_api.ipynb.")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
logging.info("Configuraciones de Pandas para visualización aplicadas.")
# Out:
# 2025-10-07 00:24:37,871 - INFO - Inicio del notebook 001_cali_api.ipynb.
# 2025-10-07 00:24:37,872 - INFO - Configuraciones de Pandas para visualización aplicadas.

# %%
# --- Celda 3: Carga de Variables de Entorno y Rutas (Modificada) ---

# Ruta al archivo .env (ajústala si es necesario)
ENV_FILE_PATH = '../.env/.env' 

# RUTA DE SALIDA: donde se guardará el nuevo CSV con los datos de la API
RAW_API_CSV_PATH = '../datos_brutos/api/001_Local_cali_api.csv'

# Ruta para el archivo JSON que guardará el estado de la extracción
STATE_FILE_PATH = '../datos_brutos/api/001_Local_cali_api.json'

# --- El resto del código de esta celda para cargar las claves API se mantiene igual ---
logging.info(f"Cargando variables de entorno desde: {ENV_FILE_PATH}")
if os.path.exists(ENV_FILE_PATH):
    load_dotenv(ENV_FILE_PATH)
    logging.info(".env encontrado y cargado.")
else:
    logging.error(f"Archivo .env NO encontrado en {ENV_FILE_PATH}.")
    raise FileNotFoundError(f"Asegúrate de que el archivo .env esté en la ruta correcta: {os.path.abspath(ENV_FILE_PATH)}")

GOOGLE_MAPS_API_KEYS = [os.getenv('GOOGLE_MAPS_API_KEY_1')] # Y las demás que tengas
GOOGLE_MAPS_API_KEYS = [key for key in GOOGLE_MAPS_API_KEYS if key]
if not GOOGLE_MAPS_API_KEYS:
    raise ValueError("No se encontraron claves API de Google Maps en el .env.")
logging.info(f"{len(GOOGLE_MAPS_API_KEYS)} clave(s) API de Google Maps cargada(s).")
# Out:
# 2025-10-07 00:24:37,878 - INFO - Cargando variables de entorno desde: ../.env/.env
# 2025-10-07 00:24:37,880 - INFO - .env encontrado y cargado.
# 2025-10-07 00:24:37,880 - INFO - 1 clave(s) API de Google Maps cargada(s).

# %%
# --- Celda 4: Gestión de Clientes API y Rotación (SIMPLIFICADA) ---
logging.info("Configurando clientes de la API de Google Maps y lógica de rotación.")

if not GOOGLE_MAPS_API_KEYS:
    raise ValueError("La lista de claves API está vacía. No se pueden crear clientes.")

# Creamos una cola (deque) de clientes de Google Maps, uno por cada clave
gmaps_clients = deque([googlemaps.Client(key=key) for key in GOOGLE_MAPS_API_KEYS])
logging.info(f"Se crearon {len(gmaps_clients)} clientes de Google Maps.")

def get_current_gmaps_client():
    """Devuelve el cliente activo actual (el primero de la cola)."""
    return gmaps_clients[0]

def rotate_gmaps_client():
    """Rota el cliente al final de la cola. Si solo hay uno, no hace nada visible."""
    if len(gmaps_clients) > 1:
        logging.warning("Rotando cliente de API. La clave actual puede haber alcanzado su límite.")
        gmaps_clients.rotate(-1) # Mueve el primer elemento al final
        logging.info(f"Nuevo cliente de API activo.")
        time.sleep(2) # Pequeña pausa al rotar
    else:
        logging.warning("Intento de rotar, pero solo hay una clave API disponible.")
        # Podríamos añadir una pausa más larga aquí si la única clave falla repetidamente
        time.sleep(10) 
        
    return get_current_gmaps_client()

logging.info("Gestor de clientes API listo.")
# Out:
# 2025-10-07 00:24:37,889 - INFO - Configurando clientes de la API de Google Maps y lógica de rotación.
# 2025-10-07 00:24:37,890 - INFO - API queries_quota: 60
# 2025-10-07 00:24:37,891 - INFO - Se crearon 1 clientes de Google Maps.
# 2025-10-07 00:24:37,891 - INFO - Gestor de clientes API listo.

# %%
# --- Celda 5: Funciones de Extracción para Google Places (CORREGIDA) ---
logging.info("Definiendo funciones para buscar y obtener detalles de lugares.")

MAX_RETRIES_PER_KEY = 3

# (La función text_search_paginated se mantiene igual, no necesita cambios)
def text_search_paginated(query, client):
    """
    Realiza una búsqueda de texto y maneja la paginación para obtener
    todos los Place IDs relevantes.
    """
    all_place_ids = []
    try:
        logging.info(f"Realizando búsqueda inicial para: '{query}'")
        response = client.places(query=query)
        all_place_ids.extend([place['place_id'] for place in response.get('results', [])])
        
        next_page_token = response.get('next_page_token')
        
        while next_page_token:
            logging.info("Paginación: Obteniendo siguiente página de resultados...")
            time.sleep(2) # Pausa obligatoria de Google
            response = client.places(page_token=next_page_token)
            all_place_ids.extend([place['place_id'] for place in response.get('results', [])])
            next_page_token = response.get('next_page_token')
        
        logging.info(f"Búsqueda para '{query}' completada. Se encontraron {len(all_place_ids)} lugares.")
        return all_place_ids

    except googlemaps.exceptions.ApiError as e:
        logging.error(f"Error de API en Text Search para '{query}': {e}")
        if e.status == 'OVER_QUERY_LIMIT':
            return "API_ERROR"
        return []
    except Exception as e:
        logging.error(f"Error inesperado en Text Search para '{query}': {e}")
        return []

def get_place_details(place_id, client):
    """
    Obtiene los detalles de un lugar usando su Place ID, solicitando los campos específicos.
    """
    # --- LISTA DE CAMPOS CORREGIDA ---
    fields_to_request = [
        'place_id',
        'name',
        'formatted_address',
        'geometry',
        'type',  # CORRECCIÓN: 'types' a 'type' (singular)
        'rating',
        'user_ratings_total',
        'reviews',
        'price_level',
        'opening_hours',
        'website',
        'international_phone_number',
        'wheelchair_accessible_entrance',
        'reservable',
        'business_status'
    ]
    
    try:
        details = client.place(
            place_id=place_id, 
            fields=fields_to_request, 
            language='es'
        )
        return details.get('result', {})
    except googlemaps.exceptions.ApiError as e:
        logging.error(f"Error de API obteniendo detalles para Place ID '{place_id}': {e}")
        return "API_ERROR"

# (La función process_query_and_get_ids se mantiene igual, no necesita cambios)
def process_query_and_get_ids(query):
    """
    Orquesta la búsqueda de una consulta completa, manejando la rotación de claves.
    """
    initial_client = get_current_gmaps_client()
    
    while True:
        client = get_current_gmaps_client()
        place_ids = text_search_paginated(query, client)
        
        if place_ids == "API_ERROR":
            rotate_gmaps_client()
            if get_current_gmaps_client() == initial_client:
                logging.error(f"Todas las claves API han fallado para la búsqueda '{query}'.")
                return []
            continue
        
        return place_ids
# Out:
# 2025-10-07 00:24:37,902 - INFO - Definiendo funciones para buscar y obtener detalles de lugares.

# %%
# --- Celda 6: Ejecución de la Extracción por Descubrimiento (Versión Extendida) ---

# --- LISTA DE LA COMPRA (VERSIÓN HIPER-LOCALIZADA Y EXTENDIDA) ---
SEARCH_QUERIES = [
    # Gastronomía y Vida Nocturna
    "restaurantes de comida típica colombiana en Cali", "restaurantes gourmet en Cali",
    "restaurantes económicos en Cali", "fritanga en Cali", "comida de mar en Cali",
    "plazas de mercado en Cali", "cafés de especialidad en Cali", "panaderías en Cali",
    "heladerías en Cali", "bares de salsa en Cali", "discotecas en Cali",
    "escuelas de salsa para turistas en Cali", "bares con música en vivo en Cali",
    # Cultura y Puntos de Interés
    "museos en Cali, Colombia", "iglesias históricas en Cali", "monumentos y estatuas en Cali",
    "teatros en Cali", "galerías de arte en Cali", "centros culturales en Cali",
    "bibliotecas públicas en Cali", "sitios turísticos en el barrio San Antonio, Cali",
    "Cerro Cristo Rey, Cali", "Gato del Río, Cali",
    # Alojamiento
    "hoteles 5 estrellas en Cali", "hoteles boutique en Cali", "hoteles económicos en Cali",
    "hostales en Cali", "apartahoteles en Cali",
    # Recreación y Naturaleza
    "parques en Cali, Colombia", "parques ecológicos cerca de Cali", "Río Pance, Cali",
    "Zoológico de Cali", "Jardín Botánico de Cali", "miradores en Cali",
    "lugares para senderismo cerca de Cali", "piscinas públicas en Cali",
    # Compras y Servicios
    "centros comerciales en Cali", "tiendas de artesanías en Cali",
    "tiendas de souvenirs en Cali", "casas de cambio en Cali",
    # Bienestar
    "spas en Cali", "gimnasios en Cali", "centros de yoga en Cali"
]

def load_processed_ids_from_csv():
    """Función auxiliar para leer los IDs del CSV si el estado no existe."""
    try:
        if os.path.exists(RAW_API_CSV_PATH):
            df_existente = pd.read_csv(RAW_API_CSV_PATH)
            logging.info(f"Archivo CSV existente encontrado. Cargando {len(df_existente['place_id'].unique())} IDs ya procesados.")
            return set(df_existente['place_id'].dropna().unique())
    except Exception as e:
        logging.error(f"No se pudo leer el archivo CSV para cargar IDs previos: {e}")
    return set()

def load_state():
    """Carga el estado desde JSON. Si no existe, intenta cargar desde el CSV."""
    if os.path.exists(STATE_FILE_PATH):
        with open(STATE_FILE_PATH, 'r') as f:
            state = json.load(f)
            # Aseguramos que los IDs estén en un set para búsquedas rápidas
            state['processed_place_ids'] = set(state.get('processed_place_ids', []))
            return state
    # Si no hay archivo de estado, creamos uno a partir del CSV existente
    return {'processed_place_ids': load_processed_ids_from_csv()}

def save_state(state):
    """Guarda el estado a JSON, convirtiendo el set a lista para la serialización."""
    state_to_save = state.copy()
    state_to_save['processed_place_ids'] = list(state.get('processed_place_ids', []))
    with open(STATE_FILE_PATH, 'w') as f:
        json.dump(state_to_save, f, indent=4)

def run_extraction():
    logging.info("--- INICIANDO EXTRACCIÓN POR DESCUBRIMIENTO (VERSIÓN ROBUSTA) ---")
    state = load_state()
    processed_place_ids = state.get('processed_place_ids', set())
    
    file_exists = os.path.exists(RAW_API_CSV_PATH)
    
    try:
        # Iteramos SIEMPRE sobre todas las consultas
        for i, query in enumerate(SEARCH_QUERIES):
            logging.info(f"\nProcesando consulta ({i+1}/{len(SEARCH_QUERIES)}): '{query}'")
            
            place_ids_found = process_query_and_get_ids(query)
            new_places_found = 0
            
            for place_id in place_ids_found:
                # La lógica clave: nos saltamos lo que ya tenemos
                if place_id in processed_place_ids:
                    logging.debug(f"Place ID {place_id} ya procesado. Omitiendo.")
                    continue

                new_places_found += 1
                logging.info(f"Nuevo lugar encontrado! Obteniendo detalles para Place ID: {place_id}")
                details = get_place_details(place_id, get_current_gmaps_client())
                
                if details and details != "API_ERROR":
                    # ... (la lógica para extraer y aplanar 'place_data' es la misma)
                    reviews_text = [r.get('text', '') for r in details.get('reviews', []) if r.get('text')]
                    place_data = {
                        'place_id': details.get('place_id'),
                        'nombre_google': details.get('name'),
                        'direccion': details.get('formatted_address'),
                        'latitud': details.get('geometry', {}).get('location', {}).get('lat'),
                        'longitud': details.get('geometry', {}).get('location', {}).get('lng'),
                        'categorias_google': ', '.join(details.get('types', [])),
                        'calificacion': details.get('rating'),
                        'total_calificaciones': details.get('user_ratings_total'),
                        'comentarios': " | ".join(reviews_text),
                        'nivel_precios': details.get('price_level'),
                        'horarios': json.dumps(details.get('opening_hours', {}), ensure_ascii=False),
                        'telefono': details.get('international_phone_number'),
                        'sitio_web': details.get('website'),
                        'entrada_accesible': details.get('wheelchair_accessible_entrance'),
                        'es_reservable': details.get('reservable'),
                        'estado_negocio': details.get('business_status')
                    }
                    
                    df_to_append = pd.DataFrame([place_data])
                    df_to_append.to_csv(RAW_API_CSV_PATH, mode='a', header=not file_exists, index=False)
                    file_exists = True
                    
                    processed_place_ids.add(place_id)
                
                elif details == "API_ERROR":
                    logging.warning(f"Error de API persistente para {place_id}. Rotando clave.")
                    rotate_gmaps_client()
                
                time.sleep(0.5)
            
            logging.info(f"Consulta '{query}' completada. Se encontraron {new_places_found} lugares nuevos.")
            # Guardamos el estado después de cada consulta completa
            state['processed_place_ids'] = processed_place_ids
            save_state(state)

    except KeyboardInterrupt:
        logging.warning("Extracción interrumpida por el usuario.")
    finally:
        save_state(state)
        logging.info(f"Proceso finalizado. Estado guardado. Total de lugares únicos en la base de datos: {len(processed_place_ids)}")

# --- Ejecutar la función principal ---
run_extraction()
# Out:
# 2025-10-07 00:24:37,916 - INFO - --- INICIANDO EXTRACCIÓN POR DESCUBRIMIENTO (VERSIÓN ROBUSTA) ---
# 2025-10-07 00:24:37,977 - INFO - Archivo CSV existente encontrado. Cargando 2042 IDs ya procesados.
# 2025-10-07 00:24:37,983 - INFO -
# Procesando consulta (1/43): 'restaurantes de comida típica colombiana en Cali'
# 2025-10-07 00:24:37,985 - INFO - Realizando búsqueda inicial para: 'restaurantes de comida típica colombiana en Cali'
# 2025-10-07 00:24:39,029 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:24:41,654 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:24:44,416 - INFO - Búsqueda para 'restaurantes de comida típica colombiana en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:24:44,417 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJqcFyKjKnMI4ReRJpOBtm9YQ
# 2025-10-07 00:24:45,123 - INFO - Consulta 'restaurantes de comida típica colombiana en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:24:45,124 - INFO -
# Procesando consulta (2/43): 'restaurantes gourmet en Cali'
# 2025-10-07 00:24:45,125 - INFO - Realizando búsqueda inicial para: 'restaurantes gourmet en Cali'
# 2025-10-07 00:24:45,747 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00
- INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJCfeNocKnMI4RDWdM3lr4qVs
# 2025-10-07 00:26:52,301 - INFO - Consulta 'bares con música en vivo en Cali' completada. Se encontraron 7 lugares nuevos.
# 2025-10-07 00:26:52,303 - INFO -
# Procesando consulta (14/43): 'museos en Cali, Colombia'
# 2025-10-07 00:26:52,304 - INFO - Realizando búsqueda inicial para: 'museos en Cali, Colombia'
# 2025-10-07 00:26:52,723 - INFO - Búsqueda para 'museos en Cali, Colombia' completada. Se encontraron 17 lugares.
# 2025-10-07 00:26:52,723 - INFO - Consulta 'museos en Cali, Colombia' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:26:52,725 - INFO -
# Procesando consulta (15/43): 'iglesias históricas en Cali'
# 2025-10-07 00:26:52,725 - INFO - Realizando búsqueda inicial para: 'iglesias históricas en Cali'
# 2025-10-07 00:26:53,234 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:26:55,761 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:26:58,251 - INFO - Búsqueda para 'iglesias históricas en Cali' completada. Se encontraron 53 lugares.
# 2025-10-07 00:26:58,252 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ8RE6oSWmMI4RZz_mPnb71gY
# 2025-10-07 00:26:58,906 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJW1WXmG-oMI4RQJ2ZcbAJpyI
# 2025-10-07 00:26:59,572 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJI527j1mmMI4Rb5r1TYVBQsM
# 2025-10-07 00:27:00,292 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJWwfnVm-mMI4RmwVbQo_TMLg
# 2025-10-07 00:27:01,008 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJo6KFWIemMI4RO6Ox9SFwSo4
# 2025-10-07 00:27:01,724 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ-zV-PlymMI4RvixgMGPZH-4
# 2025-10-07 00:27:02,363 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJG52dx-WhMI4R_92NqpVp7s4
# 2025-10-07 00:27:03,056 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJeXCwW2SmMI4RLFVbtFHII8g
# 2025-10-07 00:27:03,722 - INFO - Consulta 'iglesias históricas en Cali' completada. Se encontraron 8 lugares nuevos.
# 2025-10-07 00:27:03,727 - INFO -
# Procesando consulta (16/43): 'monumentos y estatuas en Cali'
# 2025-10-07 00:27:03,728 - INFO - Realizando búsqueda inicial para: 'monumentos y estatuas en Cali'
# 2025-10-07 00:27:04,211 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:06,647 - INFO - Búsqueda para 'monumentos y estatuas en Cali' completada. Se encontraron 26 lugares.
# 2025-10-07 00:27:06,648 - INFO - Consulta 'monumentos y estatuas en Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:27:06,650 - INFO -
# Procesando consulta (17/43): 'teatros en Cali'
# 2025-10-07 00:27:06,650 - INFO - Realizando búsqueda inicial para: 'teatros en Cali'
# 2025-10-07 00:27:07,057 - INFO - Búsqueda para 'teatros en Cali' completada. Se encontraron 3 lugares.
# 2025-10-07 00:27:07,057 - INFO - Consulta 'teatros en Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:27:07,058 - INFO -
# Procesando consulta (18/43): 'galerías de arte en Cali'
# 2025-10-07 00:27:07,059 - INFO - Realizando búsqueda inicial para: 'galerías de arte en Cali'
# 2025-10-07 00:27:07,567 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:10,190 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:12,792 - INFO - Búsqueda para 'galerías de arte en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:27:12,794 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJfVLpk3-nMI4RkJiRING4ZXE
# 2025-10-07 00:27:13,497 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJGV5YQVenMI4RHN5zTyRCYuk
# 2025-10-07 00:27:14,214 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ1StTFsOnMI4RCxy1tQ1cd-g
# 2025-10-07 00:27:14,913 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJjYDu-CWnMI4RCiZAwxeg-Wg
# 2025-10-07 00:27:15,550 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJxRg_TYSmMI4R4g67XwmvSD8
# 2025-10-07 00:27:16,211 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJQfQDfhSmMI4RtlAoyN71gGg
# 2025-10-07 00:27:16,852 - INFO - Consulta 'galerías de arte en Cali' completada. Se encontraron 6 lugares nuevos.
# 2025-10-07 00:27:16,856 - INFO -
# Procesando consulta (19/43): 'centros culturales en Cali'
# 2025-10-07 00:27:16,857 - INFO - Realizando búsqueda inicial para: 'centros culturales en Cali'
# 2025-10-07 00:27:17,400 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:19,960 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:22,427 - INFO - Búsqueda para 'centros culturales en Cali' completada. Se encontraron 51 lugares.
# 2025-10-07 00:27:22,428 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJeRXdSn2mMI4RaSvWGlv2Jm0
# 2025-10-07 00:27:23,080 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJy3cmJT2mMI4RMeee4cI_ozs
# 2025-10-07 00:27:23,843 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJuZTHWmWmMI4RM-xVCcL-hPk
# 2025-10-07 00:27:24,560 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJL6OCIYOoMI4RAnNyARFv0MA
# 2025-10-07 00:27:25,207 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJTbyKpGSmMI4R1FCDVdD_yQE
# 2025-10-07 00:27:25,888 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJbTt8z3-mMI4RXxSenRyRGS0
# 2025-10-07 00:27:26,607 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJIbHgnpymMI4R_por2dBI2vA
# 2025-10-07 00:27:27,259 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJbbhm73ymMI4Ra3xbt1hyEUw
# 2025-10-07 00:27:27,936 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJCSozbMOnMI4REJN6d4mTspg
# 2025-10-07 00:27:28,600 - INFO - Consulta 'centros culturales en Cali' completada. Se encontraron 9 lugares nuevos.
# 2025-10-07 00:27:28,604 - INFO -
# Procesando consulta (20/43): 'bibliotecas públicas en Cali'
# 2025-10-07 00:27:28,605 - INFO - Realizando búsqueda inicial para: 'bibliotecas públicas en Cali'
# 2025-10-07 00:27:29,060 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:31,737 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:34,223 - INFO - Búsqueda para 'bibliotecas públicas en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:27:34,224 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJH2PtaLOnMI4ReAWOsds25T8
# 2025-10-07 00:27:34,899 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJM9Go9XimMI4RWScN69N4Wss
# 2025-10-07 00:27:35,616 - INFO - Consulta 'bibliotecas públicas en Cali' completada. Se encontraron 2 lugares nuevos.
# 2025-10-07 00:27:35,617 - INFO -
# Procesando consulta (21/43): 'sitios turísticos en el barrio San Antonio, Cali'
# 2025-10-07 00:27:35,618 - INFO - Realizando búsqueda inicial para: 'sitios turísticos en el barrio San Antonio, Cali'
# 2025-10-07 00:27:36,258 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:39,006 - INFO - Búsqueda para 'sitios turísticos en el barrio San Antonio, Cali' completada. Se encontraron 21 lugares.
# 2025-10-07 00:27:39,009 - INFO - Consulta 'sitios turísticos en el barrio San Antonio, Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:27:39,014 - INFO -
# Procesando consulta (22/43): 'Cerro Cristo Rey, Cali'
# 2025-10-07 00:27:39,015 - INFO - Realizando búsqueda inicial para: 'Cerro Cristo Rey, Cali'
# 2025-10-07 00:27:39,406 - INFO - Búsqueda para 'Cerro Cristo Rey, Cali' completada. Se encontraron 2 lugares.
# 2025-10-07 00:27:39,410 - INFO - Consulta 'Cerro Cristo Rey, Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:27:39,414 - INFO -
# Procesando consulta (23/43): 'Gato del Río, Cali'
# 2025-10-07 00:27:39,415 - INFO - Realizando búsqueda inicial para: 'Gato del Río, Cali'
# 2025-10-07 00:27:39,824 - INFO - Búsqueda para 'Gato del Río, Cali' completada. Se encontraron 1 lugares.
# 2025-10-07 00:27:39,825 - INFO - Consulta 'Gato del Río, Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:27:39,826 - INFO -
# Procesando consulta (24/43): 'hoteles 5 estrellas en Cali'
# 2025-10-07 00:27:39,826 - INFO - Realizando búsqueda inicial para: 'hoteles 5 estrellas en Cali'
# 2025-10-07 00:27:40,514 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:43,308 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:46,156 - INFO - Búsqueda para 'hoteles 5 estrellas en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:27:46,158 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJH__FNQCnMI4RxLgT-hTXdCE
# 2025-10-07 00:27:46,805 - INFO - Consulta 'hoteles 5 estrellas en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:27:46,807 - INFO -
# Procesando consulta (25/43): 'hoteles boutique en Cali'
# 2025-10-07 00:27:46,807 - INFO - Realizando búsqueda inicial para: 'hoteles boutique en Cali'
# 2025-10-07 00:27:47,403 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:50,284 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:53,446 - INFO - Búsqueda para 'hoteles boutique en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:27:53,446 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJFW2_yTehMI4RvgQWwM4qlPg
# 2025-10-07 00:27:54,150 - INFO - Consulta 'hoteles boutique en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:27:54,152 - INFO -
# Procesando consulta (26/43): 'hoteles económicos en Cali'
# 2025-10-07 00:27:54,152 - INFO - Realizando búsqueda inicial para: 'hoteles económicos en Cali'
# 2025-10-07 00:27:54,866 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:27:57,590 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:00,604 - INFO - Búsqueda para 'hoteles económicos en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:00,605 - INFO - Consulta 'hoteles económicos en Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:28:00,606 - INFO -
# Procesando consulta (27/43): 'hostales en Cali'
# 2025-10-07 00:28:00,606 - INFO - Realizando búsqueda inicial para: 'hostales en Cali'
# 2025-10-07 00:28:01,124 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:03,957 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:06,653 - INFO - Búsqueda para 'hostales en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:06,654 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJTUFPn7enMI4RNN5VADf9f-k
# 2025-10-07 00:28:07,359 - INFO - Consulta 'hostales en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:28:07,361 - INFO -
# Procesando consulta (28/43): 'apartahoteles en Cali'
# 2025-10-07 00:28:07,361 - INFO - Realizando búsqueda inicial para: 'apartahoteles en Cali'
# 2025-10-07 00:28:07,984 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:10,716 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:13,685 - INFO - Búsqueda para 'apartahoteles en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:13,685 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJOYaQCmimMI4R8_TTqSRhang
# 2025-10-07 00:28:14,328 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJS_BDT26mMI4Rk-21GggRJaQ
# 2025-10-07 00:28:14,987 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJb2PFwqCoMI4RdcLTzHQiWVE
# 2025-10-07 00:28:15,653 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJUxc-76KoMI4RKGDpWNcZodQ
# 2025-10-07 00:28:16,318 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJLbeRpkenMI4RyqE-_qVlBao
# 2025-10-07 00:28:16,979 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJf7GPh2ymMI4R-jlpnNx8NdM
# 2025-10-07 00:28:17,702 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJd82NlJSnMI4RpaQqZYFugTw
# 2025-10-07 00:28:18,418 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ2VJKef2nMI4RpuaubTIU4Sw
# 2025-10-07 00:28:19,119 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJZQvn58ynMI4R1xT1q9ifgG4
# 2025-10-07 00:28:19,769 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJDSARR7OpMI4R3K6XeZcHcbw
# 2025-10-07 00:28:20,413 - INFO - Consulta 'apartahoteles en Cali' completada. Se encontraron 10 lugares nuevos.
# 2025-10-07 00:28:20,415 - INFO -
# Procesando consulta (29/43): 'parques en Cali, Colombia'
# 2025-10-07 00:28:20,415 - INFO - Realizando búsqueda inicial para: 'parques en Cali, Colombia'
# 2025-10-07 00:28:20,995 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:23,504 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:26,123 - INFO - Búsqueda para 'parques en Cali, Colombia' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:26,124 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJMRUAU5imMI4RjI2027b7uDM
# 2025-10-07 00:28:26,772 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJl1nDG6GmMI4R16RjrVXh_aE
# 2025-10-07 00:28:27,532 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJPZ0iXgCnMI4Rc4QREILsg34
# 2025-10-07 00:28:28,170 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJNbSFDLWnMI4Rj2Qy4o3h5Kc
# 2025-10-07 00:28:28,862 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJGWc1HzqmMI4R2FKGsbsvynU
# 2025-10-07 00:28:29,579 - INFO - Consulta 'parques en Cali, Colombia' completada. Se encontraron 5 lugares nuevos.
# 2025-10-07 00:28:29,581 - INFO -
# Procesando consulta (30/43): 'parques ecológicos cerca de Cali'
# 2025-10-07 00:28:29,581 - INFO - Realizando búsqueda inicial para: 'parques ecológicos cerca de Cali'
# 2025-10-07 00:28:30,055 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:32,560 - INFO - Búsqueda para 'parques ecológicos cerca de Cali' completada. Se encontraron 31 lugares.
# 2025-10-07 00:28:32,561 - INFO - Consulta 'parques ecológicos cerca de Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:28:32,563 - INFO -
# Procesando consulta (31/43): 'Río Pance, Cali'
# 2025-10-07 00:28:32,563 - INFO - Realizando búsqueda inicial para: 'Río Pance, Cali'
# 2025-10-07 00:28:33,010 - INFO - Búsqueda para 'Río Pance, Cali' completada. Se encontraron 3 lugares.
# 2025-10-07 00:28:33,011 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ0cEDIwCjMI4RpE8PQCi1b3U
# 2025-10-07 00:28:33,677 - INFO - Consulta 'Río Pance, Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:28:33,679 - INFO -
# Procesando consulta (32/43): 'Zoológico de Cali'
# 2025-10-07 00:28:33,679 - INFO - Realizando búsqueda inicial para: 'Zoológico de Cali'
# 2025-10-07 00:28:34,096 - INFO - Búsqueda para 'Zoológico de Cali' completada. Se encontraron 1 lugares.
# 2025-10-07 00:28:34,096 - INFO - Consulta 'Zoológico de Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:28:34,097 - INFO -
# Procesando consulta (33/43): 'Jardín Botánico de Cali'
# 2025-10-07 00:28:34,098 - INFO - Realizando búsqueda inicial para: 'Jardín Botánico de Cali'
# 2025-10-07 00:28:34,475 - INFO - Búsqueda para 'Jardín Botánico de Cali' completada. Se encontraron 1 lugares.
# 2025-10-07 00:28:34,476 - INFO - Consulta 'Jardín Botánico de Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:28:34,477 - INFO -
# Procesando consulta (34/43): 'miradores en Cali'
# 2025-10-07 00:28:34,477 - INFO - Realizando búsqueda inicial para: 'miradores en Cali'
# 2025-10-07 00:28:35,018 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:37,578 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:40,121 - INFO - Búsqueda para 'miradores en Cali' completada. Se encontraron 46 lugares.
# 2025-10-07 00:28:40,122 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJQbzZHT-mMI4Rfoc3spw5lrY
# 2025-10-07 00:28:40,760 - INFO - Consulta 'miradores en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:28:40,762 - INFO -
# Procesando consulta (35/43): 'lugares para senderismo cerca de Cali'
# 2025-10-07 00:28:40,762 - INFO - Realizando búsqueda inicial para: 'lugares para senderismo cerca de Cali'
# 2025-10-07 00:28:41,243 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:43,921 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:46,646 - INFO - Búsqueda para 'lugares para senderismo cerca de Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:46,647 - INFO - Consulta 'lugares para senderismo cerca de Cali' completada. Se encontraron 0 lugares nuevos.
# 2025-10-07 00:28:46,649 - INFO -
# Procesando consulta (36/43): 'piscinas públicas en Cali'
# 2025-10-07 00:28:46,649 - INFO - Realizando búsqueda inicial para: 'piscinas públicas en Cali'
# 2025-10-07 00:28:47,086 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:49,630 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:52,218 - INFO - Búsqueda para 'piscinas públicas en Cali' completada. Se encontraron 43 lugares.
# 2025-10-07 00:28:52,218 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ36j464OoMI4R_Q0WEI1fh7s
# 2025-10-07 00:28:52,926 - INFO - Consulta 'piscinas públicas en Cali' completada. Se encontraron 1 lugares nuevos.
# 2025-10-07 00:28:52,928 - INFO -
# Procesando consulta (37/43): 'centros comerciales en Cali'
# 2025-10-07 00:28:52,929 - INFO - Realizando búsqueda inicial para: 'centros comerciales en Cali'
# 2025-10-07 00:28:53,544 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:56,317 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:28:58,979 - INFO - Búsqueda para 'centros comerciales en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:28:58,980 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJRW4l9eynMI4Ry0ik2vxfJSQ
# 2025-10-07 00:28:59,639 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJIdbBkBWmMI4Rg62ECqWvBjM
# 2025-10-07 00:29:00,299 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJWS4c2xWmMI4RPu3BS9GgnQ0
# 2025-10-07 00:29:00,948 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJE8oRf2imMI4RzZoCkVy_JPo
# 2025-10-07 00:29:01,630 - INFO - Consulta 'centros comerciales en Cali' completada. Se encontraron 4 lugares nuevos.
# 2025-10-07 00:29:01,632 - INFO -
# Procesando consulta (38/43): 'tiendas de artesanías en Cali'
# 2025-10-07 00:29:01,632 - INFO - Realizando búsqueda inicial para: 'tiendas de artesanías en Cali'
# 2025-10-07 00:29:02,153 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:04,717 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:07,273 - INFO - Búsqueda para 'tiendas de artesanías en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:29:07,273 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJKUNvNRCpMI4RxV09Y-qH4Js
# 2025-10-07 00:29:07,979 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJcXi6TbOnMI4RJJAGEitTTXQ
# 2025-10-07 00:29:08,695 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJz7LtZZCnMI4RiFgxYFdSACk
# 2025-10-07 00:29:09,405 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ_WBszlmnMI4RP41Hu-wdETc
# 2025-10-07 00:29:10,034 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJy-Djm2imMI4RDWM-v3ojQAg
# 2025-10-07 00:29:10,672 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ2zH6wGamMI4RdzAPuoeYTjg
# 2025-10-07 00:29:11,462 - INFO - Consulta 'tiendas de artesanías en Cali' completada. Se encontraron 6 lugares nuevos.
# 2025-10-07 00:29:11,464 - INFO -
# Procesando consulta (39/43): 'tiendas de souvenirs en Cali'
# 2025-10-07 00:29:11,464 - INFO - Realizando búsqueda inicial para: 'tiendas de souvenirs en Cali'
# 2025-10-07 00:29:11,968 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:14,544 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:17,206 - INFO - Búsqueda para 'tiendas de souvenirs en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:29:17,206 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJwwZzXxamMI4Ror3d3XiAr2w
# 2025-10-07 00:29:17,845 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ86toFD6nMI4RwaWcczyjaZA
# 2025-10-07 00:29:18,526 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJm8ZyWBSnMI4R57XRZAO-gJM
# 2025-10-07 00:29:19,179 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ1WhD32mnMI4RhA4_1aEgrzA
# 2025-10-07 00:29:19,826 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJuxrqwRimMI4R9XolxzrV51g
# 2025-10-07 00:29:20,474 - INFO - Consulta 'tiendas de souvenirs en Cali' completada. Se encontraron 5 lugares nuevos.
# 2025-10-07 00:29:20,479 - INFO -
# Procesando consulta (40/43): 'casas de cambio en Cali'
# 2025-10-07 00:29:20,480 - INFO - Realizando búsqueda inicial para: 'casas de cambio en Cali'
# 2025-10-07 00:29:22,254 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:24,752 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:27,428 - INFO - Búsqueda para 'casas de cambio en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:29:27,429 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJu3MiUz6mMI4R90BHbjcEGZs
# 2025-10-07 00:29:28,102 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJWWV3eximMI4RpKybvpG36hU
# 2025-10-07 00:29:28,766 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJt_wASainMI4RdfK8Gv3mAQw
# 2025-10-07 00:29:29,417 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJxVVo5i-mMI4R7M1eLQ9zqAc
# 2025-10-07 00:29:30,064 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJW44Sej2mMI4RC9LyqKyh5xo
# 2025-10-07 00:29:30,704 - INFO - Consulta 'casas de cambio en Cali' completada. Se encontraron 5 lugares nuevos.
# 2025-10-07 00:29:30,707 - INFO -
# Procesando consulta (41/43): 'spas en Cali'
# 2025-10-07 00:29:30,708 - INFO - Realizando búsqueda inicial para: 'spas en Cali'
# 2025-10-07 00:29:31,140 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:33,707 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:36,457 - INFO - Búsqueda para 'spas en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:29:36,457 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJMYWaMAmnMI4RsUh45V6iAIY
# 2025-10-07 00:29:37,163 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJVVW0SoWmMI4RSUdHQeuOCa8
# 2025-10-07 00:29:37,879 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJx49dhkWnMI4RNEC6pSC0Fxc
# 2025-10-07 00:29:38,578 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJOcdB7cYFOo4RLdZ-NwSENCI
# 2025-10-07 00:29:39,228 - INFO - Consulta 'spas en Cali' completada. Se encontraron 4 lugares nuevos.
# 2025-10-07 00:29:39,232 - INFO -
# Procesando consulta (42/43): 'gimnasios en Cali'
# 2025-10-07 00:29:39,233 - INFO - Realizando búsqueda inicial para: 'gimnasios en Cali'
# 2025-10-07 00:29:39,735 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:42,295 - INFO - Paginación: Obteniendo siguiente página de resultados...
# 2025-10-07 00:29:44,874 - INFO - Búsqueda para 'gimnasios en Cali' completada. Se encontraron 60 lugares.
# 2025-10-07 00:29:44,875 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ07jwLuOnMI4RPFYdFx1oXak
# 2025-10-07 00:29:45,519 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJncHbWJ-oMI4RvKCVmStaqEw
# 2025-10-07 00:29:46,174 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJJyREl1KnMI4Rm8S9l4DCpCM
# 2025-10-07 00:29:46,817 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJ
- INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJHTKCIg2nMI4RsIF1i3gMH0Q
# 2025-10-07 00:30:13,207 - INFO - Nuevo lugar encontrado! Obteniendo detalles para Place ID: ChIJfXfS6u-nMI4RgfzlWW3Ri7E
# 2025-10-07 00:30:13,926 - INFO - Consulta 'centros de yoga en Cali' completada. Se encontraron 15 lugares nuevos.
# 2025-10-07 00:30:13,933 - INFO - Proceso finalizado. Estado guardado. Total de lugares únicos en la base de datos: 2237

# %%
# --- Carga del Dataset ---
try:
    data_folder = '../datos_brutos/api/'
    file_name = '001_Local_cali_api.csv'
    file_path = os.path.join(data_folder, file_name)
    
    df_api = pd.read_csv(file_path)
    logging.info(f"Dataset '{file_name}' cargado exitosamente.")
except FileNotFoundError:
    logging.error(f"Error: El archivo no se encontró en la ruta: {file_path}")
# Out:
# 2025-10-07 00:30:13,993 - INFO - Dataset '001_Local_cali_api.csv' cargado exitosamente.

# %%
df_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   place_id              2237 non-null   object
#  1   nombre_google         2237 non-null   object
#  2   direccion             2237 non-null   object
#  3   latitud               2237 non-null   float64
#  4   longitud              2237 non-null   float64
#  5   categorias_google     2237 non-null   object
#  6   calificacion          2138 non-null   float64
#  7   total_calificaciones  2138 non-null   float64
#  8   comentarios           2054 non-null   object
#  9   nivel_precios         328 non-null    float64
#  10  horarios              2237 non-null   object
#  11  telefono              1797 non-null   object
#  12  sitio_web             975 non-null    object
#  13  entrada_accesible     1041 non-null   object
#  14  es_reservable         372 non-null    object
#  15  estado_negocio        2236 non-null   object
# dtypes: float64(5), object(11)
# memory usage: 279.8+ KB

# %%
df_api.head(365)
# Out:
#                         place_id                       nombre_google  \
# 0    ChIJ4ym1rp-mMI4RdMtQYqwmVGE                   La Casona Valluna
# 1    ChIJpT3NWaqnMI4RJ0B8s1ESQ40               Restaurante La Abuela
# 2    ChIJJSW8MIOmMI4Rtvn2QSI02is                         La Comitiva
# 3    ChIJ66yQrX2mMI4RjMrUlemZdy0            El Zaguán de San Antonio
# 4    ChIJe3iuqS2nMI4RvZ7C18ALXFo  Mi Tierra - Restaurante colombiano
# ..                           ...                                 ...
# 360  ChIJNeouYVOmMI4RnzJwmzjYjeI                  Panadería Matecaña
# 361  ChIJfXc4nHCoMI4RoVYXHG1xv9o       Panadería y Pastelería Lizpan
# 362  ChIJq7IKZDSmMI4RMp8-Tm___3U         Panadería Brisas de Salomia
# 363  ChIJ24jxmeemMI4RFOvYfozAd1E               Panaderia La Panameña
# 364  ChIJZXsfGIKoMI4RdB6YJnFKmUA           Panaderia La Super ALAMOS
#
#                                              direccion   latitud   longitud  \
# 0    Cra. 38d #4C - 54, Nueva Granada, Cali, Valle ...  3.426279 -76.546359
# 1    Cl. 52 #13A-24, Comuna 8, Cali, Valle del Cauc...  3.444960 -76.499559
# 2    Cl. 4 #3432, El Sindicato, Cali, Valle del Cau...  3.434618 -76.544993
# 3    Cra. 12 #1-29, San Cayetano, Cali, Valle del C...  3.446042 -76.540740
# 4    Cl. 2 #12A-05, COMUNA 3, Cali, Valle del Cauca...  3.445091 -76.540113
# ..                                                 ...       ...        ...
# 360  Cra. 12 #42-103, Comuna 8, Cali, Valle del Cau...  3.448389 -76.504160
# 361          COMUNA 6, Cali, Valle del Cauca, Colombia  3.488983 -76.490751
# 362  Cra 2 #46 - 23, Esmeralda, Cali, Valle del Cau...  3.467035 -76.505836
# 363  Cra. 32 #322, San Carlos, Cali, Valle del Cauc...  3.424586 -76.511840
# 364  Calle 55AN #Av2BN, Cl. 112b, Cali, Valle del C...  3.483853 -76.509065
#
#                                      categorias_google  calificacion  \
# 0    establishment, food, point_of_interest, restau...           4.4
# 1    establishment, food, point_of_interest, restau...           4.3
# 2    establishment, food, point_of_interest, restau...           4.7
# 3    establishment, food, point_of_interest, restau...           4.2
# 4    establishment, food, point_of_interest, restau...           4.5
# ..                                                 ...           ...
# 360  bakery, establishment, food, point_of_interest...           4.3
# 361  bakery, establishment, food, point_of_interest...           4.2
# 362  bakery, establishment, food, point_of_interest...           4.4
# 363  bakery, establishment, food, point_of_interest...           4.3
# 364  bakery, establishment, food, point_of_interest...           4.4
#
#      total_calificaciones                                        comentarios  \
# 0                  3865.0  Terrible experiencia, las marranitas llegaron ...
# 1                   343.0  Es un restaurante el cual he conocido casi la ...
# 2                  2281.0  Restaurante románticamente ambientado, situado...
# 3                  2600.0  Mi completa admiración hacia este lugar ya que...
# 4                   260.0  La comida es buena, el lugar está muy adornado...
# ..                    ...                                                ...
# 360                 544.0  Unos productos con muy buen sabor. | Siempre m...
# 361                 526.0  Muy buena atención, todo delicioso 🤗 | Primero...
# 362                 187.0  Muy buen sitio excelente comida | Es una buena...
# 363                 743.0  Si vas de paso y buscas desayunar aquí en la P...
# 364                 657.0  Sinceramente sin mentiras,la mejor parva que h...
#
#      nivel_precios                                           horarios  \
# 0              2.0  {"open_now": true, "periods": [{"close": {"day...
# 1              2.0  {"open_now": true, "periods": [{"close": {"day...
# 2              3.0  {"open_now": false, "periods": [{"close": {"da...
# 3              2.0  {"open_now": false, "periods": [{"close": {"da...
# 4              NaN  {"open_now": false, "periods": [{"close": {"da...
# ..             ...                                                ...
# 360            NaN  {"open_now": false, "periods": [{"close": {"da...
# 361            NaN  {"open_now": false, "periods": [{"close": {"da...
# 362            1.0  {"open_now": false, "periods": [{"close": {"da...
# 363            1.0  {"open_now": true, "periods": [{"open": {"day"...
# 364            1.0  {"open_now": false, "periods": [{"close": {"da...
#
#             telefono                                          sitio_web  \
# 0    +57 310 4472694                    http://www.lacasonavalluna.com/
# 1    +57 602 4382765  https://www.paginasamarillas.com.co/empresas/r...
# 2    +57 315 0713719                 https://restaurantelacomitiva.com/
# 3    +57 602 8938021  https://www.facebook.com/pages/El-Zaguan-De-Sa...
# 4    +57 301 1781322    https://www.facebook.com/mitierratradicion2017/
# ..               ...                                                ...
# 360  +57 316 5133927                                                NaN
# 361              NaN                                                NaN
# 362  +57 602 4494529                                                NaN
# 363              NaN                                                NaN
# 364  +57 301 2875992                                                NaN
#
#     entrada_accesible es_reservable estado_negocio
# 0                True          True    OPERATIONAL
# 1                 NaN         False    OPERATIONAL
# 2                True          True    OPERATIONAL
# 3               False          True    OPERATIONAL
# 4                 NaN          True    OPERATIONAL
# ..                ...           ...            ...
# 360               NaN           NaN    OPERATIONAL
# 361               NaN           NaN    OPERATIONAL
# 362               NaN           NaN    OPERATIONAL
# 363              True           NaN    OPERATIONAL
# 364               NaN           NaN    OPERATIONAL
#
# [365 rows x 16 columns]
